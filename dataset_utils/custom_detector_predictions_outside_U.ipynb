# %% [markdown]
# # Custom detector predictions outside U
#
# Here, we validate if the custom detectors trained on subsets of Tiny images dataset behave similar on a random subset of data outside U.

# %%
import pickle
import numpy as np

# %% [markdown]
# ## Load indices of U

# %%
# U: 500k images filtered from tiny images by Percy Liang's detector that are most similar to CIFAR-10
aux_path = '../data/ti_500K_pseudo_labeled.pickle'

with open(aux_path, 'rb') as f:
    aux = pickle.load(f)
    aux_indices = aux['ti_index']

# %%
aux_indices
# Out:
# array([ 2503931, 71093249, 41345827, ..., 71911843, 62792441, 68810450],
#       dtype=int64)

# %%
# Uniformly sample random indices from tiny images which are not in aux_indices
np.random.seed(4)

not_aux_indices = []

for _ in range(250000):
    idx = np.random.randint(low=0, high=79302016)
    while idx in aux_indices:
        idx = np.random.randint(low=0, high=79302016)
    not_aux_indices.append(idx)
    
not_aux_indices.sort()

# %%
len(not_aux_indices)
# Out:
# 250000

# %%
with open('ti_250k_not_aux_indices.pickle', 'wb') as f:
    pickle.dump(not_aux_indices, f)

# %%
with open('ti_250k_not_aux_indices.txt', 'w') as f:
    f.write('\n'.join(str(idx) for idx in not_aux_indices))

# %% [markdown]
# ## Make the custom detector predictions on these images

# %%
aux_indices.sort()

# %%
len(aux_indices)
# Out:
# 500000

# %%
aux_indices[:5]
# Out:
# array([ 70,  71, 112, 176, 178], dtype=int64)

# %%
out_U = []
for i in range(1000000, 1350000):
    if i not in aux_indices:
        out_U.append(i)
    if len(out_U) == 250000:
        break
print(len(out_U))
# Out:
# 250000

# %%
out_U[-5:]
# Out:
# [1253282, 1253283, 1253284, 1253285, 1253286]

# %%
out_U[:5]
# Out:
# [1000000, 1000001, 1000002, 1000003, 1000004]

# %%
out_U_pos = [i + 1 - 1000000 for i in out_U]

# %%
out_U_pos[:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
out_U_pos[-5:]
# Out:
# [253283, 253284, 253285, 253286, 253287]

# %%
chunks = []
start = 1
for i in range(1, len(out_U_pos)):
    if out_U_pos[i] != out_U_pos[i-1] + 1:
        chunks.append((start, out_U_pos[i-1]))
        start = out_U_pos[i]
chunks.append((start, out_U_pos[-1]))

print(chunks)
# Out:
# [(1, 2134), (2136, 2525), (2527, 2646), (2648, 2722), (2724, 2856), (2858, 2904), (2906, 3269), (3271, 3380), (3382, 3463), (3465, 3503), (3505, 3535), (3537, 3542), (3544, 3755), (3757, 4492), (4494, 4512), (4514, 5260), (5262, 5414), (5416, 5584), (5586, 5604), (5606, 5658), (5660, 5742), (5744, 5929), (5931, 6197), (6199, 6348), (6350, 6410), (6412, 7274), (7276, 7612), (7614, 7930), (7932, 7936), (7938, 7940), (7942, 7945), (7948, 7953), (7955, 7959), (7961, 7964), (7966, 8019), (8021, 8130), (8132, 8154), (8156, 8219), (8221, 8244), (8246, 8305), (8307, 8349), (8351, 8369), (8371, 8410), (8412, 8412), (8414, 8470), (8472, 8497), (8499, 8523), (8525, 8534), (8536, 8573), (8575, 8643), (8645, 8656), (8658, 8703), (8705, 8728), (8730, 8730), (8732, 8737), (8739, 8777), (8779, 8797), (8799, 8816), (8818, 8878), (8880, 8939), (8942, 8949), (8951, 8983), (8985, 9114), (9116, 9123), (9125, 9131), (9133, 9137), (9139, 9173), (9175, 9179), (9181, 9233), (9235, 9287), (9289, 9348), (9350, 9357), (9359, 9430), (9432, 9457), (9459, 9493), (9495, 9513), (9515, 9564), (9566, 9608), (9610, 9638), (9640, 9688), (9690, 9699), (9701, 10167), (10169, 10216), (10218, 11324), (11326, 11431), (11433, 11542), (11544, 11643), (11645, 12625), (12627, 12630), (12632, 12702), (12706, 12708), (12710, 12710), (12712, 12720), (12722, 12783), (12786, 12789), (12791, 12944), (12946, 13051), (13053, 13241), (13243, 13413), (13415, 14072), (14074, 14571), (14573, 14989), (14991, 15911), (15913, 17563), (17565, 18022), (18024, 18374), (18376, 18394), (18396, 19250), (19252, 19788), (19790, 21035), (21037, 22026), (22028, 23932), (23934, 23968), (23970, 23973), (23976, 23980), (23982, 24126), (24128, 25449), (25451, 25696), (25698, 25790), (25792, 25906), (25908, 26164), (26166, 26198), (26200, 26432), (26434, 26865), (26867, 26867), (26869, 27051), (27053, 27958), (27960, 28072), (28074, 28373), (28375, 28417), (28419, 28484), (28486, 28561), (28563, 28749), (28751, 28754), (28756, 28821), (28823, 28919), (28921, 28944), (28946, 30067), (30069, 30460), (30462, 31049), (31051, 31617), (31619, 33529), (33531, 33846), (33848, 34236), (34238, 34923), (34925, 34928), (34930, 35006), (35008, 35011), (35013, 35341), (35343, 35453), (35455, 35596), (35598, 35694), (35696, 35849), (35851, 35943), (35945, 36094), (36096, 36164), (36166, 36438), (36440, 36447), (36449, 36463), (36465, 36945), (36947, 37729), (37731, 38497), (38499, 38849), (38851, 38861), (38863, 39524), (39526, 39526), (39528, 39528), (39530, 39531), (39533, 39571), (39573, 39573), (39575, 39595), (39598, 39598), (39600, 39717), (39720, 40218), (40220, 40257), (40259, 40374), (40376, 40607), (40609, 40714), (40716, 40941), (40943, 41170), (41174, 41207), (41209, 41515), (41517, 41527), (41529, 41536), (41538, 41538), (41540, 41557), (41559, 41560), (41562, 41741), (41743, 41812), (41814, 41834), (41837, 41879), (41881, 41972), (41974, 42038), (42040, 42077), (42079, 42079), (42081, 42116), (42118, 42627), (42629, 42650), (42652, 42720), (42722, 42747), (42750, 43452), (43454, 43750), (43752, 43879), (43881, 44342), (44344, 44899), (44901, 45104), (45106, 45808), (45810, 46556), (46558, 49347), (49349, 50257), (50259, 50658), (50660, 51458), (51460, 52868), (52870, 53226), (53228, 53316), (53318, 53626), (53628, 53705), (53707, 53707), (53709, 53930), (53932, 54595), (54598, 54598), (54600, 54602), (54604, 54606), (54608, 54614), (54616, 54624), (54626, 54630), (54632, 54634), (54638, 54638), (54640, 54651), (54654, 54658), (54660, 54665), (54667, 54668), (54671, 54674), (54676, 54680), (54682, 54683), (54686, 54689), (54691, 54700), (54703, 54712), (54714, 54725), (54727, 54732), (54734, 54746), (54749, 54754), (54756, 54756), (54759, 54759), (54761, 54761), (54763, 54763), (54765, 54765), (54768, 54769), (54772, 54772), (54774, 54775), (54777, 54781), (54783, 54974), (54976, 54985), (54987, 55124), (55126, 55207), (55209, 55279), (55281, 55297), (55299, 55339), (55341, 55460), (55462, 55464), (5546 ...

# %%
print(len(chunks))
# Out:
# 3017

# %%
count = 0
for chunk in chunks:
    count += chunk[1] - chunk[0] + 1
print(count)
# Out:
# 250000
